# %% [markdown]
# # Explore Feature Datasets
# Run `python generate_data.py` first to create the parquet files.

# %%
import pandas as pd

transactions = pd.read_parquet('data/transactions.parquet')
activity = pd.read_parquet('data/cardholder_activity.parquet')

# %%
print(f'Transactions: {transactions.shape}')
transactions.head(3)
# Out:
# Transactions: (1000, 5)
#    cardholder_id                  event_timestamp  transaction_amount  \
# 0              1 2026-05-06 23:31:46.873334+00:00               70.39
# 1              1 2026-05-09 23:31:46.873334+00:00              184.69
# 2              1 2026-05-12 23:31:46.873334+00:00               30.10
#
#    transaction_frequency  average_spend
# 0                      5         222.32
# 1                      3         280.84
# 2                      4         118.97

# %%
print(f'Cardholder activity: {activity.shape}')
activity.head(3)
# Out:
# Cardholder activity: (1000, 4)
#    cardholder_id                  event_timestamp  \
# 0              1 2026-05-07 05:31:46.873334+00:00
# 1              1 2026-05-10 05:31:46.873334+00:00
# 2              1 2026-05-13 05:31:46.873334+00:00
#
#    days_since_last_transaction  transaction_velocity
# 0                            0                  3.40
# 1                            3                  2.00
# 2                            3                  2.15
